# %%
import requests
from bs4 import BeautifulSoup
import re

# %%
url = 'https://cssc.cyc.org.tw/'

res=requests.get(url)
soup=BeautifulSoup(res.content,'html.parser')
temp=soup.findAll('big', id='gym_on')
temp[0]
# Out:
# <big id="gym_on"></big>

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="zh-tw">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type">
# <title>中山運動中心</title>
# <!-- Bootstrap -->
# <link href="https://cssc.cyc.org.tw/contents/frontend/lib/bootstrap/css/bootstrap.css" rel="stylesheet"/>
# <link href="https://cssc.cyc.org.tw/contents/frontend/css/non-responsive.css" rel="stylesheet"/>
# <link href="https://cssc.cyc.org.tw/contents/frontend/css/style.css?1535363601" rel="stylesheet" type="text/css"/>
# <link href="https://cssc.cyc.org.tw/contents/frontend/css/main.css?1535363601" rel="stylesheet" type="text/css"/>
# <link href="https://cssc.cyc.org.tw/contents/frontend/css/layout.css?1535363601" rel="stylesheet" type="text/css"/>
# <!-- ico -->
# <link href="https://cssc.cyc.org.tw/contents/frontend/images/favicon.ico" rel="shortcut icon">
# <link href="https://cssc.cyc.org.tw/contents/frontend/images/favicon.ico" rel="bookmark">
# <!--fancyBox-->
# <link href="https://cssc.cyc.org.tw/contents/frontend/lib/fancybox/jquery.fancybox.css?v=2.1.5" media="screen" rel="stylesheet" type="text/css">
# <link href="https://cssc.cyc.org.tw/contents/frontend/css/a_style.css" rel="stylesheet" type="text/css">
# <!-- HTML5 shim and Respond.js for IE8 support of HTML5 elements and media queries -->
# <!-- WARNING: Respond.js doesn't work if you view the page via file:// -->
# <!--[if lt IE 9]>
#       <script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script>
#       <script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>
#     <![endif]-->
# <!--
# <script>
# 	alert("");
# </script>
# -->
# <style>
# 	#map {
#     	height: 100%;
#     }
#
#     strong { font-size: 30px}
#
#     .three_colon {
# 	    color: white!important;
# 	    overflow:hidden;
# 	    display: block;
# 	    position:absolute!important;
# 	    padding: 0;
# 	    margin: -1px 0 0 -10px;
# 	    width: 1px;
# 	}
# </style> <link href="https://cssc.cyc.org.tw/sys_css/index" rel="stylesheet" type="text/css"/>
# </link></link></link></link></meta></meta></head>
# <body>
# <header>
# <div><a class="sr-only mainContent" href="#mainContent" onclick="accesskey_click()" onkeypress="accesskey_keypress()" tabindex="1" title="移置內容">跳到主要內容區塊</a></div>
# <!-- <a href="#sitemap" title="移置網站導覽" class="sr-only Sitemap" tabindex="2">移置網站導覽</a> -->
# <!--選單-->
# <nav id="NAV">
# <div class="row">
# <div class="col-sm-4">
# <h1>
# <a href="https://cssc.cyc.org.tw/" tabindex="1" title="回首頁">
# <img alt="回首頁-中山運動中心" src="https://cssc.cyc.org.tw/upload/logo/top_logo_zhongshan.png" title="回首頁"/>
# </a>
# </h1>
# </div>
# <div class="col-sm-8">
# <div class="subBtn">
# <ul>
# <a accesskey="U" class="sr-only" href="#U" id="AU" name="U" tabindex="1" title="右上方功能區塊">:::</a>
# <li><a href="https://cssc.cyc.org.tw/" tabindex="1" title="回首頁">回首頁</a></li>
# <li><a href="https://cssc.cyc.org.tw/sitemap" id="sitemap" tabindex="1" title="網站導覽">網站導覽</a></li>
# <li><a href="http://booking.tpsc.sporetrofit.com" tabindex="1" target="_blank" title="台北市運動中心場地預約-另開連結">臺北市運動中心場地預約</a></li>
# <li><a href="https://cssc.cyc.org.tw/problem" tabindex="1" target="_blank" title="另開新視窗-常見問題">常見問題</a></li>
# <li><a href="https://testcssc.cyc.org.tw/IISystem/Portal/root/" style="color: rgb(56,118,29)" tabindex="1" target="_new" title="另開新視窗-運動課程">運動課程</a></li>
# <li><a href="https://cssc.cyc.org.tw/device" id="mobile" tabindex="1" title="手機版">手機版</a></li>
# <li class="fb2">
# <a href="https://www.facebook.com/cssccyc/" tabindex="1" target="_blank" title="另開新視窗-facebook粉絲團">
# <img alt="另開新視窗-facebook粉絲團" src="https://cssc.cyc.org.tw/contents/frontend/images/fb0.png"/> facebook粉絲團
# 	                    </a>
# </li>
# </ul>
# </div>
# <ul class="nav">
# <li><a class="active" href="https://cssc.cyc.org.tw/news/0" tabindex="1" title="訊息公告">訊息公告</a></li>
# <li><a href="https://cssc.cyc.org.tw/sportscenter/1" tabindex="1" title="樓層介紹">樓層介紹</a></li>
# <li><a href="http://cyc.xuanen.com.tw/tp01.aspx" tabindex="1" target="_new" title="另開新視窗-場地預訂">場地預訂</a></li>
# <li><a href="https://cssc.cyc.org.tw/traffic/1" tabindex="1" title="交通資訊">交通資訊</a></li>
# <li><a href="https://cssc.cyc.org.tw/accessibility/1" tabindex="1" title="無障礙設施">無障礙設施</a></li>
# </ul>
# </div>
# </div><!--rowEND-->
# </nav>
# </header> <header class="header3" style="display: none;">
# <!--選單-->
# <nav id="number">
# <ul>
# <li class="sub-cr"><img alt="" src="https://cssc.cyc.org.tw/contents/frontend/images/number.png"/>中心場館人數</li>
# <li id="gym"><b>健身房 </b><big id="gym_on"></big><b> 人 </b><i> 容留<b id="gym_all"></b>人</i></li>
# <li id="swim"><b>游泳池 </b><big id="swim_on"></big><b> 人 </b><i> 容留<b id="swim_all"></b>人</i></li>
# <li id="ice"><b>冰宮 </b><big id="ice_on"></big><b> 人 </b><i> 容留<b id="ice_all"></b>人</i></li>
# <!--      	  <li><i> ( 每分鐘更新一次 )  最後更新：<b id="showbox"></b></i></li> -->
# </ul>
# </nav></header></body></html><!--rowEND-->
#
#
# <!--主版位開始-->
# <section class="wrapper w1">
# <!--廣告區-->
# <!-- 子站台 banner -->
# <section class="slider">
# <div class="carousel slide" data-ride="carousel" id="carousel-example-generic">
# <noscript>
# 		 		           中山運動中心 - 中山運動中心 輪播圖 1 <a href="https://testcssc.cyc.org.tw/IISystem/Portal/root/" title="了解更多">了解更多</a>
# 	        	          運動課程 中山運動中心 -  輪播圖 2 <a href="https://testcssc.cyc.org.tw/IISystem/Portal/root/" title="了解更多">了解更多</a>
# 	        	          中山運動中心外觀 中山運動中心 -  輪播圖 3 <a href="https://testcssc.cyc.org.tw/IISystem/Portal/root/" title="了解更多">了解更多</a>
# </noscript>
# <aside class="topnav">
# <div>
# <h4></h4>
# <h2>中山運動中心</h2>
# <p class="MT30" style="line-height: 2em;">
# 		        		        		        中山運動中心		        		        	        </p>
# </div>
# <p class="pt"><a href="https://testcssc.cyc.org.tw/IISystem/Portal/root/" tabindex="2" title="了解更多">了解更多</a></p>
# </aside>
# <!-- Indicators -->
# <ol class="carousel-indicators">
# <li class="active" data-slide-to="0" data-target="#carousel-example-generic"></li>
# <li class="" data-slide-to="1" data-target="#carousel-example-generic"></li>
# <li class="" data-slide-to="2" data-target="#carousel-example-generic"></li>
# </ol>
# <!-- Wrapper for slides -->
# <div class="carousel-inner photoList" role="listbox">
# <div class="item active">
# <a class="photoList-a" style="height: 657.13px;" tabindex="2">
# <aside class="banner_bg_0"></aside>
# </a>
# </div>
# <div class="item ">
# <a class="photoList-a" style="height: 657.13px;" tabindex="2">
# <aside class="banner_bg_1"></aside>
# </a>
# </div>
# <div class="item ">
# <a class="photoList-a" style="height: 657.13px;" tabindex="2">
# <aside class="banner_bg_2"></aside>
# </a>
# </div>
# <!-- Controls -->
# <a class="left carousel-control" data-slide="prev" href="#carousel-example-generic" role="button" tabindex="2">
# <span aria-hidden="true" class="glyphicon glyphicon-chevron-left" title="上一個"></span>
# <span class="sr-only">Previous</span>
# </a>
# <a class="right carousel-control" data-slide="next" href="#carousel-example-generic" role="button" tabindex="2">
# <span aria-hidden="true" class="glyphicon glyphicon-chevron-right" title="下一個"></span>
# <span class="sr-only">Next</span>
# </a>
# </div>
# </div></section>
# <!-- 主站台 banner -->
# <!--主功能區-->
# <section class="cyc-index" id="mainContent">
# <div class="TopImg"><img alt="" src="https://cssc.cyc.org.tw/contents/frontend/images/bg-shoes.png"/></div>
# <div class="TopImg2"><img alt="" src="https://cssc.cyc.org.tw/contents/frontend/images/bg-phone.png"/></div>
# <div class="container">
# <h2 style="font-size: 36px; text-align: center;">
# <a accesskey="C" class="sr-only" href="#C" id="AC" name="C" tabindex="3" title="中央內容區塊">:::</a>
# 	        消息公告
# 	    </h2>
# <div class="row">
# <div class=" col-xs-3">
# <h4 class=" text-center" style="min-height: 39px;">「臺北市跨域產業</h4>
# <a href="https://cssc.cyc.org.tw/news_content/1051" tabindex="3" title="了解更多「臺北市跨域產業的內容">
# <aside style="height: 189px;">
# <h6>2018-08-10</h6>
# <p tabindex="3">「臺北市跨域產業合作與商機媒合計畫」活動</p>
# </aside>
# </a>
# </div>
# <div class=" col-xs-3">
# <h4 class="h4-1 text-center" style="min-height: 39px;">徵 櫃台正職人員</h4>
# <a href="https://cssc.cyc.org.tw/news_content/1020" tabindex="3" title="了解更多徵 櫃台正職人員的內容">
# <aside style="height: 189px;">
# <h6>2018-07-16</h6>
# <p tabindex="3">徵 櫃台正職人員</p>
# </aside>
# </a>
# </div>
# <div class=" col-xs-3">
# <h4 class=" text-center" style="min-height: 39px;">課程單堂體驗</h4>
# <a href="https://cssc.cyc.org.tw/news_content/970" tabindex="3" title="了解更多課程單堂體驗的內容">
# <aside style="height: 189px;">
# <h6>2018-06-08</h6>
# <p tabindex="3">課程單堂體驗</p>
# </aside>
# </a>
# </div>
# <div class=" col-xs-3">
# <h4 class="h4-1 text-center" style="min-height: 39px;">9-10月課程簡</h4>
# <a href="https://cssc.cyc.org.tw/news_content/948" tabindex="3" title="了解更多9-10月課程簡的內容">
# <aside style="height: 189px;">
# <h6>2018-05-30</h6>
# <p tabindex="3">107年9-10月運動課程簡章電子檔搶先看</p>
# </aside>
# </a>
# </div>
# </div><!--rowEnd-->
# <p class="pt PTB30 text-center">
# <a href="https://cssc.cyc.org.tw/news" tabindex="3" title="更多的消息公告">
# 	        	更多
# 	        </a>
# </p>
# </div><!--containerEnd-->
# </section><!--主功能區end-->
# <section class="centers">
# <noscript>
# <a href="https://tycsc.cyc.org.tw/" title="場所-桃園國民運動中心">場所-桃園國民運動中心</a>
# <a href="http://cssc.cyc.org.tw/" title="場所-中山運動中心">場所-中山運動中心</a>
# <a href="https://ngsc.cyc.org.tw/" title="場所-南港運動中心">場所-南港運動中心</a>
# <a href="https://xysc.cyc.org.tw/" title="場所-信義運動中心">場所-信義運動中心</a>
# <a href="https://dasc.cyc.org.tw/" title="場所-大安運動中心">場所-大安運動中心</a>
# <a href="http://wssc.cyc.org.tw/" title="場所-文山運動中心">場所-文山運動中心</a>
# <a href="https://nhsc.cyc.org.tw/" title="場所-內湖運動中心">場所-內湖運動中心</a>
# <a href="http://lzcsc.cyc.org.tw/" title="場所-蘆洲國民運動中心">場所-蘆洲國民運動中心</a>
# <a href="https://tccsc.cyc.org.tw/" title="場所-土城國民運動中心">場所-土城國民運動中心</a>
# <a href="http://xzcsc.cyc.org.tw/" title="場所-汐止國民運動中心">場所-汐止國民運動中心</a>
# <a href="https://yhcsc.cyc.org.tw/" title="場所-永和國民運動中心">場所-永和國民運動中心</a>
# <a href="http://cmcsc.cyc.org.tw/" title="場所-朝馬國民運動中心">場所-朝馬國民運動中心</a>
# <a href="https://styac.cyc.org.tw/" title="場所-南區青少年活動中心">場所-南區青少年活動中心</a>
# <a href="https://zlcsc.cyc.org.tw/" title="場所-中壢國民運動中心">場所-中壢國民運動中心</a>
# </noscript>
# <div class="Toparrow1"><a href="javascript:;" id="btnPrev" tabindex="3" title="運動中心場所 往左一頁"><img alt="運動中心場所 往左一頁" src="https://cssc.cyc.org.tw/contents/frontend/images/arrow1.png"/></a></div>
# <div class="Toparrow2"><a href="javascript:;" id="btnNext" tabindex="3" title="運動中心場所 往右一頁"><img alt="運動中心場所 往右一頁" src="https://cssc.cyc.org.tw/contents/frontend/images/arrow2.png"/></a></div>
# <h2 class="MT50 MB40" style="font-size: 36px; text-align: center; color: #fff;">運動中心場館</h2>
# <div class="container">
# <div class="row">
# <div class="col-sm-1-5 col-xs-6">
# <a href="https://tycsc.cyc.org.tw/" tabindex="3" title="場所-桃園國民運動中心">
# <img alt="場所-桃園國民運動中心" class="venue_img" src="https://cssc.cyc.org.tw/upload/venue_logo/photo.jpg"/>
# </a>
# <h4>桃園</h4>
# <p>國民運動中心</p>
# </div>
# <div class="col-sm-1-5 col-xs-6">
# <a href="http://cssc.cyc.org.tw/" tabindex="3" title="場所-中山運動中心">
# <img alt="場所-中山運動中心" class="venue_img" src="https://cssc.cyc.org.tw/upload/venue_logo/中山.jpg"/>
# </a>
# <h4>中山</h4>
# <p>運動中心</p>
# </div>
# <div class="col-sm-1-5 col-xs-6">
# <a href="https://ngsc.cyc.org.tw/" tabindex="3" title="場所-南港運動中心">
# <img alt="場所-南港運動中心" class="venue_img" src="https://cssc.cyc.org.tw/upload/venue_logo/13450775_1720885168149420_125210172670924696_n.jpg"/>
# </a>
# <h4>南港</h4>
# <p>運動中心</p>
# </div>
# <div class="col-sm-1-5 col-xs-6">
# <a href="https://xysc.cyc.org.tw/" tabindex="3" title="場所-信義運動中心">
# <img alt="場所-信義運動中心" class="venue_img" src="https://cssc.cyc.org.tw/upload/venue_logo/氣宇軒昂21.jpg"/>
# </a>
# <h4>信義</h4>
# <p>運動中心</p>
# </div>
# <div class="col-sm-1-5 col-xs-6">
# <a href="https://dasc.cyc.org.tw/" tabindex="3" title="場所-大安運動中心">
# <img alt="場所-大安運動中心" class="venue_img" src="https://cssc.cyc.org.tw/upload/venue_logo/大安.jpg"/>
# </a>
# <h4>大安</h4>
# <p>運動中心</p>
# </div>
# <div class="col-sm-1-5 col-xs-6">
# <a href="http://wssc.cyc.org.tw/" tabindex="3" title="場所-文山運動中心">
# <img alt="場所-文山運動中心" class="venue_img" src="https://cssc.cyc.org.tw/upload/venue_logo/文山.jpg"/>
# </a>
# <h4>文山</h4>
# <p>運動中心</p>
# </div>
# <div class="col-sm-1-5 col-xs-6">
# <a href="https://nhsc.cyc.org.tw/" tabindex="3" title="場所-內湖運動中心">
# <img alt="場所-內湖運動中心" class="venue_img" src="https://cssc.cyc.org.tw/upload/venue_logo/iess_iot_fact2_3_800x600.jpg"/>
# </a>
# <h4>內湖</h4>
# <p>運動中心</p>
# </div>
# <div class="col-sm-1-5 col-xs-6">
# <a href="http://lzcsc.cyc.org.tw/" tabindex="3" title="場所-蘆洲國民運動中心">
# <img alt="場所-蘆洲國民運動中心" class="venue_img" src="https://cssc.cyc.org.tw/upload/venue_logo/蘆洲.jpg"/>
# </a>
# <h4>蘆洲</h4>
# <p>國民運動中心</p>
# </div>
# <div class="col-sm-1-5 col-xs-6">
# <a href="https://tccsc.cyc.org.tw/" tabindex="3" title="場所-土城國民運動中心">
# <img alt="場所-土城國民運動中心" class="venue_img" src="https://cssc.cyc.org.tw/upload/venue_logo/IMG_6119.JPG"/>
# </a>
# <h4>土城</h4>
# <p>國民運動中心</p>
# </div>
# <div class="col-sm-1-5 col-xs-6">
# <a href="http://xzcsc.cyc.org.tw/" tabindex="3" title="場所-汐止國民運動中心">
# <img alt="場所-汐止國民運動中心" class="venue_img" src="https://cssc.cyc.org.tw/upload/venue_logo/汐止.jpg"/>
# </a>
# <h4>汐止</h4>
# <p>國民運動中心</p>
# </div>
# <div class="col-sm-1-5 col-xs-6">
# <a href="https://yhcsc.cyc.org.tw/" tabindex="3" title="場所-永和國民運動中心">
# <img alt="場所-永和國民運動中心" class="venue_img" src="https://cssc.cyc.org.tw/upload/venue_logo/永和.jpg"/>
# </a>
# <h4>永和</h4>
# <p>國民運動中心</p>
# </div>
# <div class="col-sm-1-5 col-xs-6">
# <a href="http://cmcsc.cyc.org.tw/" tabindex="3" title="場所-朝馬國民運動中心">
# <img alt="場所-朝馬國民運動中心" class="venue_img" src="https://cssc.cyc.org.tw/upload/venue_logo/台中朝馬.jpg"/>
# </a>
# <h4>朝馬</h4>
# <p>國民運動中心</p>
# </div>
# <div class="col-sm-1-5 col-xs-6">
# <a href="https://styac.cyc.org.tw/" tabindex="3" title="場所-南區青少年活動中心">
# <img alt="場所-南區青少年活動中心" class="venue_img" src="https://cssc.cyc.org.tw/upload/venue_logo/南區門口.jpg"/>
# </a>
# <h4>南區</h4>
# <p>青少年活動中心</p>
# </div>
# <div class="col-sm-1-5 col-xs-6">
# <a href="https://zlcsc.cyc.org.tw/" tabindex="3" title="場所-中壢國民運動中心">
# </a>
# <h4>中壢</h4>
# <p>國民運動中心</p>
# </div>
# </div>
# </div> <!--rowend-->
# </section>
# <!--運動中心簡介-->
# <section class="prdList relaxList video">
# <div class="row text-center">
# <!-- 子站使用 -->
# <div class="col-sm-8">
# <h2 class="h1-1">運動中心簡介</h2>
# <a class="various fancybox.iframe" href="https://www.youtube.com/embed/IowTVhH-Wjo?autoplay=1" tabindex="2" title="影片預覽圖-中山區運動中心介紹影片">
# <!--           	     <i class="playIcon"></i> -->
# <img alt="" src="https://img.youtube.com/vi/IowTVhH-Wjo/0.jpg" style="width: 546px; height: 318px;"/>
# <h4>中山區運動中心介紹</h4>
# </a>
# </div>
# <div class="col-sm-4">
# <h2 class="h1-1">於facebook跟隨我們</h2>
# <div class="fb-page" data-adapt-container-width="true" data-height="355" data-hide-cover="false" data-href="https://www.facebook.com/cssccyc/" data-show-facepile="true" data-small-header="false" data-tabs="timeline" data-width="243" tabindex="2">
# <blockquote cite="https://www.facebook.com/cssccyc/" class="fb-xfbml-parse-ignore">
# <a href="https://www.facebook.com/cssccyc/" title="中山運動中心">中山運動中心</a>
# </blockquote>
# </div>
# </div>
# <!-- //子站使用 -->
# </div>
# </section>
# <!--作品展示End-->
# </section>
# <!--主版位end-->
# <!--footer-->
# <footer>
# <div class="container">
# <div class="row">
# <div class="footer_left col-md-4 MT20">
# <a accesskey="F" class="sr-only" href="#F" id="AF" name="F" style="color: #fff;" tabindex="999" title="下方功能區塊">:::</a>
# <h5>中山運動中心</h5>
# <p>地址：10491 臺北市中山區中山北路二段44巷2號</p>
# <p>電話：Tel：02-2581-1060 (代表號)</p>
# <p>傳真：Fax：02-2560-4894</p>
# <p>電子信箱：E-mail：cssc@cyc.tw</p>
# <p>開館時間：Opening Times：06：00 ~ 22：00<br/>(農曆除夕、初一不開放；如遇颱風等天災，依照臺北市政府公告停止上班上課，暫時不對外開放)<br/>Open all year around,except the Chinese New Year Eve and the first day of the Chinese Lunar Year</p>
# <p><a href="https://www.handicap-free.nat.gov.tw/Applications/Detail?category=20170426170227" tabindex="99" target="_blank" title="無障礙網站">
# <img alt="通過A優先等級無障礙網頁檢測" border="0" src="/contents/frontend/images/handicap_free.jpg" style="width: 160px;"/>
# </a></p>
# </div>
# <div class="footer_right col-md-8">
# <div class="col-sm-3 col-md-6"></div>
# <div class="col-sm-9 col-md-6">
# <p><b>相關連結</b></p>
# <p><a href="https://www.cyccea.org.tw/IISystem/Portal/blue/" tabindex="999" target="_blank" title="另開新視窗-救國團終身學習中心">救國團終身學習中心</a></p>
# <p><a href="http://sc.cyc.org.tw/" tabindex="999" target="_blank" title="另開新視窗-救國團受託經營管理各運動中心">救國團受託經營管理各運動中心</a></p>
# <p><a href="https://tycsc.cyc.org.tw/" tabindex="999" target="_blank" title="另開新視窗-桃園國民運動中心">桃園國民運動中心</a></p>
# <p><a href="http://cssc.cyc.org.tw/" tabindex="999" target="_blank" title="另開新視窗-中山運動中心">中山運動中心</a></p>
# <p><a href="https://ngsc.cyc.org.tw/" tabindex="999" target="_blank" title="另開新視窗-南港運動中心">南港運動中心</a></p>
# <p><a href="https://xysc.cyc.org.tw/" tabindex="999" target="_blank" title="另開新視窗-信義運動中心">信義運動中心</a></p>
# <p><a href="https://dasc.cyc.org.tw/" tabindex="999" target="_blank" title="另開新視窗-大安運動中心">大安運動中心</a></p>
# <p><a href="http://wssc.cyc.org.tw/" tabindex="999" target="_blank" title="另開新視窗-文山運動中心">文山運動中心</a></p>
# <p><a href="https://nhsc.cyc.org.tw/" tabindex="999" target="_blank" title="另開新視窗-內湖運動中心">內湖運動中心</a></p>
# <p><a href="http://lzcsc.cyc.org.tw/" tabindex="999" target="_blank" title="另開新視窗-蘆洲國民運動中心">蘆洲國民運動中心</a></p>
# <p><a href="https://tccsc.cyc.org.tw/" tabindex="999" target="_blank" title="另開新視窗-土城國民運動中心">土城國民運動中心</a></p>
# <p><a href="http://xzcsc.cyc.org.tw/" tabindex="999" target="_blank" title="另開新視窗-汐止國民運動中心">汐止國民運動中心</a></p>
# <p><a href="https://yhcsc.cyc.org.tw/" tabindex="999" target="_blank" title="另開新視窗-永和國民運動中心">永和國民運動中心</a></p>
# <p><a href="http://cmcsc.cyc.org.tw/" tabindex="999" target="_blank" title="另開新視窗-朝馬國民運動中心">朝馬國民運動中心</a></p>
# <p><a href="https://styac.cyc.org.tw/" tabindex="999" target="_blank" title="另開新視窗-南區青少年活動中心">南區青少年活動中心</a></p>
# <p><a href="https://zlcsc.cyc.org.tw/" tabindex="999" target="_blank" title="另開新視窗-中壢國民運動中心">中壢國民運動中心</a></p>
# </div>
# </div>
# </div><!--rowEnd-->
# </div><!--containerEnd-->
# <!-- GA Code -->
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-47859141-1', 'auto');
#   ga('send', 'pageview');
#
# </script></footer><!--footerend-->
# <!--js-->
# <script src="https://cssc.cyc.org.tw/contents/frontend/js/jquery-1.11.2.min.js"></script>
# <script src="https://cssc.cyc.org.tw/contents/frontend/js/bootstrap.js"></script>
# <script src="https://cssc.cyc.org.tw/contents/frontend/lib/fancybox/jquery.fancybox.js?1535363601"></script>
# <script src="https://cssc.cyc.org.tw/contents/frontend/js/jquery.transit.min.js?1535363601"></script>
# <script src="https://cssc.cyc.org.tw/contents/frontend/js/photoshow.js"></script>
# <script>
# 	$(document).ready(function(){
#
# 		$("#gym").hide();
# 		$("#swim").hide();
# 		$("#ice").hide();
#
# 		api();
# 		setInterval(api, 60000);
#
# 		function api(){
#
# 			$.ajax({
# 				url: "https://cssc.cyc.org.tw/api",
# 				type: "POST",
# 				dataType: "json",
# 				error: function(xhr){
# 					console.log(xhr);
# 				},
# 				success: function(response){
# 					if(response.length == undefined && !(response["gym"][0].indexOf("找不到資源")!= -1))
# 					{
# 						$(".header3").show();
# 					}
# 					if(response["gym"] && !(response["gym"][0].indexOf("找不到資源")!= -1))
# 					{
# 						$("#gym").show();
# 						$('#gym_on').html(response["gym"][0]);
# 						$('#gym_all').html(response["gym"][1]);
# 					}
# 					if(response["swim"] && !(response["gym"][0].indexOf("找不到資源")!= -1))
# 					{
# 						$("#swim").show();
# 						$('#swim_on').html(response["swim"][0]);
# 						$('#swim_all').html(response["swim"][1]);
# 					}
# 					if(response["ice"] && !(response["gym"][0].indexOf("找不到資源")!= -1))
# 					{
# 						$("#ice").show();
# 						$('#ice_on').html(response["ice"][0]);
# 						$('#ice_all').html(response["ice"][1]);
# 					}
# 				},
# 				timeout: 10000
# 			});
# 		}
# 	})
# </script>
# <script>
# 	//跳至主要內容區塊
#     function accesskey_click() {
#         $('#AC').focus();
#         $('#AC').blur();
#         $('html,body').animate({ scrollTop: $('#mainContent').offset().top - 150 }, 800);
#     }
#
#     function accesskey_keypress() {
#         var keyCode;
#
#         if (window.event) {
#             keyCode = event.which || event.keyCode;
#         }
#         //按下enter跳至主要內容區塊
#         if (keyCode == 13) {
#             $('#AC').focus();
#             $('#AC').blur();
#             $('html,body').animate({ scrollTop: $('#mainContent').offset().top - 150 }, 800);
#         }
#     }
# </script><script>
# 	$(function(){
# 		photoshow();
# 		$(".various").fancybox({
# 			    maxWidth	: 800,
# 				width	    : '100%',
# 				height	    : '56.25%',
# 				fitToView	: false,
# 				autoSize	: false,
# 				closeClick	: false,
# 				openEffect	: 'none',
# 				closeEffect	: 'none'
# 		});
#
# 	});
# </script>
# <div id="fb-root"></div>
# <script>(function(d, s, id) {
#   var js, fjs = d.getElementsByTagName(s)[0];
#   if (d.getElementById(id)) return;
#   js = d.createElement(s); js.id = id;
#   js.src = "//connect.facebook.net/zh_TW/sdk.js#xfbml=1&version=v2.8&appId=248529051859356";
#   fjs.parentNode.insertBefore(js, fjs);
# }(document, 'script', 'facebook-jssdk'));</script>

# %%
import requests
import json

# %%
url = 'https://cssc.cyc.org.tw/api'
res=requests.get(url)
json.loads(res.text)
# Out:
# {'gym': ['32', '70', '0'], 'swim': ['49', '180', '0']}

# %%
json.loads(res.text)['gym'][0]
# Out:
# '32'
