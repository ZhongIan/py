# %% [markdown]
# # 參考來源
#
# https://www.youtube.com/watch?v=zzMRbrOHlrk

# %%
import requests

url = 'https://rent.591.com.tw/home/search/rsList?is_new_list=1&type=1&kind=0&searchtype=1&region=1'
res = requests.get(url)

# %%
# 404錯誤 , 可能需要 User-Agent
res.text
# Out:
# '<!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">\r\n<html>\r\n<head><title>404 Not Found</title></head>\r\n<body bgcolor="white">\r\n<h1>404 Not Found</h1>\r\n<p>The requested URL was not found on this server.<hr/>Powered by Microsoft-IIS/8.0</body>\r\n</html>\r\n'

# %%
head = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/69.0.3497.100 Safari/537.36',
    #'Cookie':'webp=1; PHPSESSID=2rb8ffppjlo1bnunplodnhlbq1; urlJumpIp=1; urlJumpIpByTxt=%E5%8F%B0%E5%8C%97%E5%B8%82; new_rent_list_kind_test=0; T591_TOKEN=2rb8ffppjlo1bnunplodnhlbq1; c10f3143a018a0513ebe1e8d27b5391c=1; _ga=GA1.3.1861890247.1538881880; _gid=GA1.3.1446476289.1538881880; _ga=GA1.4.1861890247.1538881880; _gid=GA1.4.1446476289.1538881880; is_new_index=1; is_new_index_redirect=1; 591_new_session=; _gat_UA-97423186-1=1',
    #'Referer': 'https://rent.591.com.tw/?kind=0&region=1'
}

# %%
import requests

url = 'https://rent.591.com.tw/home/search/rsList?is_new_list=1&type=1&kind=0&searchtype=1&region=1'
res = requests.get(url,headers=head)

# %%
data = res.json()

# %%
data.keys()
# Out:
# dict_keys(['status', 'data', 'records', 'is_recom', 'deal_recom', 'online_social_user'])

# %%
data['data']
# Out:
# {'topData': [{'is_new_index': 0,
#    'is_new_list': 1,
#    'type': 1,
#    'post_id': 6856372,
#    'isAd': 0,
#    'regionid': 1,
#    'photoNum': 10,
#    'classLast': 'class = "last"',
#    'detail_url': 'rent-detail-6856372.html',
#    'address': '套房出租，獨立衛浴個人洗衣機雙對外窗',
#    'img_src': 'https://hp1.591.com.tw/house/active/2010/07/01/127798255359602609_210x158.crop.jpg',
#    'alt': '台北租屋,中山租屋,獨立套房出租,套房出租，獨立衛浴個人洗衣機雙對外窗',
#    'address_2': '套房出租，獨立衛浴個人洗衣...',
#    'section_str': '中山區',
#    'region': 1,
#    'kind_str': '獨立套房',
#    'area': '7坪',
#    'price_str': '12,000元',
#    'recom_num': 0,
#    'address_3': '套房出租，獨立衛..',
#    'ico': 'rent-ico',
#    'price': '12,000',
#    'price_unit': '元/月',
#    'onepxImg': ''},
#   {'is_new_index': 0,
#    'is_new_list': 1,
#    'type': 1,
#    'post_id': 6848168,
#    'isAd': 0,
#    'regionid': 1,
#    'photoNum': 15,
#    'classLast': '',
#    'detail_url': 'rent-detail-6848168.html',
#    'address': '松江南京站【松江公園旁】五星級雅房★限女',
# ...
