# %% [markdown]
# # 參考網址
#
# https://www.youtube.com/watch?v=_0WTohwhPHk

# %%
url = 'https://buy.yungching.com.tw/region'

# %%
head = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/69.0.3497.100 Safari/537.36'}

# %%
import requests
res = requests.get(url, headers=head)

# %%
print(res.text)
# Out:
# <!DOCTYPE HTML>
# <!--[if lte IE 8]>    <html class="no-js lt-ie9" lang="zh-Hant-TW" > <![endif]-->
# <!--[if gt IE 8]><!-->
# <html dir="ltr" lang="zh-Hant-TW" itemscope itemtype="http://schema.org" >
# <!--<![endif]-->
# <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#" >
#     <meta charset="UTF-8">
#     <title> 台北市房屋。買屋、購屋、買房子、找房屋、實價登錄 | 永慶房屋 - 永慶房仲網買屋</title>
#
#     <meta name="description" content="最新台北市房屋 。最新更新時間：2018/9/29。台北市 房屋，全部6861件，新進物件669件，最新降價2689件。買屋、購屋、買房子、找房屋、實價登錄首選永慶房仲網，還有買屋注意事項、實價登錄、房貸試算、實境找房，讓買屋更省時省力。" />
#     <meta property="fb:app_id" content="320559141361882" />
#     <meta property="og:locale" content="zh_TW" />
#     <meta property="og:title" itemprop="name" content=" 台北市房屋。買屋、購屋、買房子、找房屋、實價登錄 | 永慶房屋 - 永慶房仲網買屋" />
#     <meta property="og:description" content="最新台北市房屋 。最新更新時間：2018/9/29。台北市 房屋，全部6861件，新進物件669件，最新降價2689件。買屋、購屋、買房子、找房屋、實價登錄首選永慶房仲網，還有買屋注意事項、實價登錄、房貸試算、實境找房，讓買屋更省時省力。" />
# ...
