# %% [markdown]
# ## 來源
#
# [python3-cookbook](https://python3-cookbook.readthedocs.io/zh_CN/latest/c01/p01_unpack_sequence_into_separate_variables.html)
#
#
# # 数据结构和算法
#
# ## 小計
#
#
#
# 1.  解压序列赋值给多个变量
#
# 2.  [*args]解压可迭代对象赋值给多个变量
#
# 3.  [collections.deque]保留最后 N 个元素
#
# 4.  [heapq]查找最大或最小的 N 个元素
#     *  讨论
#
# 5.  实现一个优先级队列
#
# 6.  [collections.defaultdict]字典中的键映射多个值
#
# 7.  [collections.OrderedDict]字典排序
#
# 8.  [zip]字典的运算
#
# 9.  [keys() ; items() 集合操作(&,-)]查找两字典的相同点
#
# 10.  删除序列相同元素并保持顺序
#
# 11.  [slice()]命名切片
#
# 12.  [collections.Counter]序列中出现次数最多的元素
#
# 13.  [operator.itemgetter]通过某个关键字排序一个字典列表
#
# 14.  [sorted(,key=)]排序不支持原生比较的对象
#
# 15.  [itertools.groupby]通过某个字段将记录分组
#
# 16.  [filter()]过滤序列元素
#     *  [itertools.compress]讨论
#
#
#
# 17.  从字典中提取子集
#
# 18.  [collections.namedtuple]映射名称到序列元素
#     *  讨论
#
#
# 19.  转换并同时计算数据
#
# 20.  [collections.ChainMap]合并多个字典或映射

# %% [markdown]
# # 字符串和文本
#
# 1.  [re.split() 非捕获分组，如 (?:...)]使用多个界定符分割字符串
#
#
# 2.  [str.startswith()]字符串开头或结尾匹配
#
#
# 3.  [*?]用Shell通配符匹配字符串
#
#
# 4.  [re]字符串匹配和搜索
#
#
# 5.  [re.sub()]字符串搜索和替换
#
#
# 6.  [re.IGNORECASE]字符串忽略大小写的搜索替换
#
#
# 7.  [r'"(.*?)"']最短匹配模式
#
#
# 8.  (?:.|\n)跨行匹配模式
#
#     *  讨论
#
#
# 9.  [unicodedata]将Unicode文本标准化
#
#     *  讨论
#
#
# 10.  在正则式中使用Unicode[建議安裝第三方套件]
#
#
# 11.  [str.strip() re.sub()]删除字符串中不需要的字符
#
#
# 12.  [str.translate()]审查清理文本字符串
#
#     *  讨论
#
#
# 13.  [format()]字符串对齐
#
#     *  format()
#
#
# 14.  [join()]合并拼接字符串
#
#     *  讨论
#
#
# 15.  [format() format_map() 和 vars()]字符串中插入变量
#
#
# 16.  [textwrap.fill()]以指定列宽格式化字符串
#
#     *  [os.get_terminal_size()]讨论
#
#
# 17.  [html.escape()]在字符串中处理html和xml
#
#     *  [html.parse xml.etree.ElementTree]讨论
#
#
# 18.  字符串令牌解析
#
#     *  讨论
#
#
# 19.  [3 + 4 = 7 字符解析處理]实现一个简单的递归下降分析器
#
#     *  PLY 模塊
#
#
# 20.  [b' ']字节字符串上的字符串操作
#
#     *  讨论

# %% [markdown]
# # 数字日期和时间
#
# 1.  [round()]数字的四舍五入
#
#     *  讨论
#
#
# 2.  [decimal.Decimal()]执行精确的浮点数运算
#
#     *  讨论
#
#
# 3.  [format() {0.2f >10.1f ,e}]数字的格式化输出
#
#
# 4.  二八十六进制整数
#
#
# 5.  [int.to_bytes int.from_bytes]字节到大整数的打包与解包
#
#
# 6.  [cmath numpy]复数的数学运算
#
#
# 7.  [math.isinf() float('inf')]无穷大与NaN
#
#     *  讨论
#
#
# 8.  [fractions.Fraction]分数运算
#
#
# 9.  [numpy]大型数组运算
#
#
# 10.  [np.matrix numpy.linalg]矩阵与线性代数运算
#
#
# 11.  [random]随机选择
#
#     *  [seed]讨论
#
#
# 12.  [datetime]基本的日期与时间转换
#
#     *  [dateutil.relativedelta]讨论
#
#
# 13.  计算最后一个周五的日期
#
#     *  [dateutil]讨论
#
#
# 14.  [calendar]计算当前月份的日期范围
#
#
# 15.  [datetime.strptime()]字符串转换为日期
#
#
# 16.  结合时区的日期操作
#
#     *  讨论

# %% [markdown]
# # 迭代器与生成器
#
# 1.  [next() ; StopIteration 異常]手动遍历迭代器
#
#
# 2.  [ iter() ]代理迭代
#
#    * 讨论
#
#
# 3.  [yield]使用生成器创建新的迭代模式
#
#
# 4.  [yield from]实现迭代器协议
#
#    * 讨论
#
#
# 5.  [reversed()]反向迭代
#
#    * [ reversed ]讨论
#
#
# 6.  [iter]带有外部状态的生成器函数
#
#
# 7.  [itertools.islice()]迭代器切片
#
#
# 8.  [itertools.dropwhile()]跳过可迭代对象的开始部分
#
#
# 9.  [itertools.permutations itertools.combinations]排列组合的迭代
#
#
# 10.  [enumerate()]序列上索引值迭代
#
#
# 11.  同时迭代多个序列
#
#     * 讨论
#
#
# 12.  [itertools.chain()]不同集合上元素的迭代
#
#     * 讨论
#
#
# 13.  创建数据处理管道
#
#     * 讨论
#
#
# 14.  [isinstance(x, Iterable)]展开嵌套的序列
#
#     * [yield from ; for]讨论
#
#
# 15.  [heapq.merge()]顺序迭代合并后的排序迭代对象
#
#     * 讨论
#
#
# 16.  迭代器代替while无限循环
#
#     * 讨论

# %% [markdown]
# # 文件与IO
#
# 1.  [open('rt'/'wt')]读写文本数据
#
#     * [open(f, 'rt', newline='')]讨论
#
#
# 2.  [print(, file=f)]打印输出至文件中
#
#
# 3.  [print(, sep=',', end=' ')]使用其他分隔符或行终止符打印
#
#     * 讨论
#
#
# 4.  [open(, 'rb'/'wb')]读写字节数据
#
#     * 讨论
#
#
# 5.  [open(,'xt') ]文件不存在才能写入
#
#
# 6.  [io]字符串的I/O操作
#
#
# 7.  [gzip, bz2]读写压缩文件
#
#     * [gzip.open(, 'wt', compresslevel=5)]讨论
#
#
# 8.  [functools.partial]固定大小记录的文件迭代
#
#
# 9.  [f.readinto(bytearray)]读取二进制数据到可变缓冲区中
#
#     * [memoryview()]讨论
#
#
# 10.  [mmap.mmap]内存映射的二进制文件
#
#     * [memoryview]讨论
#
#
# 11.  [os.path]文件路径名的操作
#
#
# 12.  [os.path ; .getsize() ; .exists()]测试文件是否存在
#
#
# 13.  [os.listdir()]获取文件夹中的文件列表
#
#     * [os.path ; os.stat()]讨论
#
#
# 14.  [os.listdir(b'.')]忽略文件名编码
#
#
# 15.  [f.encode(sys.getfilesystemencoding(),errors='surrogateescape')]打印不合法的文件名
#
#     * 讨论
#
#
# 16.  [io.TextIOWrapper()]增加或改变已打开文件的编码
#
#     * 讨论
#
#
# 17.  将字节写入文本文件
#
#
# 18.  将文件描述符包装成文件对象
#
#
# 19.  创建临时文件和文件夹
#
#
# 20.  [pySerial包]与串行端口的数据通信
#
#
# 21.  [pickle]序列化Python对象

# %% [markdown]
# # 数据编码和处理
#
# 1.  [csv collections.namedtuple()]读写CSV数据
# 2.  [json.dumps() ; json.loads()]读写JSON数据
#     * [json.dumps(, default) ; json.loads(, object_hook)]讨论
# 3.  [xml.etree.ElementTree.parse()]解析简单的XML数据
#     * 讨论
# 4.  [xml.etree.ElementTree.iterparse]增量式解析大型XML文件
#     * 讨论
# 5.  [xml.etree.ElementTree.Element]将字典转换为XML
#     * [xml.sax.saxutils.escape()]讨论
# 6.  解析和修改XML
#     * 讨论
# 7.  利用命名空间解析XML文档
# 8.  与关系型数据库的交互
#     * 讨论
# 9.  [binascii(小寫) ; base64(大寫)]编码和解码十六进制数
#     * 讨论
# 10.  [base64.b64encode()]编码解码Base64数据
#     * 讨论
# 11.  [struct.Struct()]读写二进制数组数据
#     * 讨论
# 12.  读取嵌套和可变长二进制数据
#     * 解二进制文件，class，簡化
#     * 解二进制文件，Metaclass 元類，簡化
#     * 更加智能
# 13.  [pandas]数据的累加与统计操作

# %% [markdown]
# # 函数
#
# 1.  可接受任意数量参数的函数
# 2.  只接受关键字参数的函数
# 3.  给函数参数增加元信息
# 4.  返回多个值的函数
# 5.  定义有默认参数的函数
#     *  讨论
# 6.  [lambda]定义匿名或内联函数
# 7.  [lambda]匿名函数捕获变量值
#     *  [lambda x, n=n:]讨论
# 8.  [functools.partial()]减少可调用对象的参数个数
#     *  讨论
# 9.  将单方法的类转换为函数
# 10.  带额外状态信息的回调函数
# 11.  内联回调函数
# 12.  [nonlocal]访问闭包中定义的变量
#     *  讨论

# %% [markdown]
# # 类与对象
#
# 1.  [str() ; repr()]改变对象的字符串显示
# 2.  [format()]自定义字符串的格式化
# 3.  [with]让对象支持上下文管理协议
# 4.  [slots]创建大量对象时节省内存方法
# 5.  [下畫線]在类中封装属性名
# 6.  [@property ]创建可管理的属性
#       * 讨论
# 7.  [super()]调用父类方法
#       * 讨论
# 8.  子类中扩展property
# 9.  [get, set, delete]创建新的类或实例属性
#       * 讨论
# 10.  使用延迟计算属性
#       * 讨论
# 11.  [setattr]简化数据结构的初始化
# 12.  [@abstractmethod]定义接口或者抽象基类
#       * 讨论
# 13.  实现数据模型的类型约束
#       * 简化--类装饰器
#       * 简化--元类
#       * [装饰器]讨论
# 14.  实现自定义容器
#       * 讨论
# 15.  属性的代理访问
#       * 讨论
# 16.  [@classmethod]在类中定义多个构造器
#       * 讨论
# 17.  创建不调用init方法的实例
# 18.  利用Mixins扩展类功能
#       * 讨论
# 19.  实现状态对象或者状态机
# 20.  [getattr()]通过字符串调用对象方法
#       * 讨论
# 21.  实现访问者模式
#       * 讨论
# 22.  不用递归实现访问者模式
# 23.  循环引用数据结构的内存管理
#       * 讨论
# 24.  [functools.total_ordering]让类支持比较操作
#       * 讨论
# 25.  创建缓存实例
#       * 讨论

# %% [markdown]
# # 元编程
#
# 1.  在函数上添加包装器
#       * 讨论
# 2.  [functools.wraps]创建装饰器时保留函数元信息
#       * 讨论
# 3.  解除一个装饰器
# 4.  定义一个带参数的装饰器
#       * 讨论
# 5.  可自定义属性的装饰器
#       * 讨论
# 6.  带可选参数的装饰器
#       * 讨论
# 7.  [inspect.signature]利用装饰器强制函数上的类型检查
# 8.  将装饰器定义为类的一部分
#       * 讨论
# 9.  将装饰器定义为类
#       * 讨论
# 10.  为类和静态方法提供装饰器
#       * 讨论
# 11.  [inspect.signature inspect.Parameter]装饰器为被包装函数增加参数
#       * 讨论
# 12.  使用装饰器扩充类的功能
# 13.  [call]使用元类控制实例的创建
#       * 讨论
# 14.  捕获类的属性定义顺序
# 15.  定义有可选参数的元类
#       * 讨论
# 16.  [inspect]*args和**kwargs的强制参数签名
#       * 讨论
# 17.  在类上强制使用编程规约
# 18.  以编程方式定义类
#       * 讨论
# 19.  在定义的时候初始化类的成员
# 20.  利用函数注解实现方法重载
#       * 讨论
# 21.  避免重复的属性方法
# 22.  定义上下文管理器的简单方法
#       * 讨论
# 23.  [locals()]在局部变量域中执行代码
# 24.  解析与分析Python源码
#       * 讨论
# 25.  [dis]拆解Python字节码
#       * 讨论

# %% [markdown]
# # 模块与包
#
# 1. 构建一个模块的层级包
#     * 讨论
# 2. 控制模块被全部导入的内容
# 3. [.]使用相对路径名导入包中子模块
# 4. [init.py]将模块分割成多个文件
#     * [需要时被加载]讨论
# 5. [init.py]利用命名空间导入目录分散的代码
# 6. [imp.reload()]重新加载模块
# 7. [main.py]运行目录或压缩文件
# 8. 读取位于包中的数据文件
#     * 讨论
# 9. 将文件夹加入到sys.path
#     * 讨论
# 10.  [importlib.import_module]通过字符串名导入模块
# 11.  [http.server]通过钩子远程加载模块{長;自定义导入器}
# 12.  导入模块的同时修改模块
# 13.  [pip install --user]安装私有的包
# 14.  [pyvenv]创建新的Python环境
# 15.  分发包
